# %%
import sympy as sp
x=sp.symbols('x')
b=0.9
g=0.9

f=(1/4*b*g)*( sp.cos(x/2)/sp.sin(x/2)**2)*1/(sp.sqrt((g**2)*sp.sin(x/2)**2-1))

# %%
f
# Out:
# 0.2025*cos(x/2)/(sqrt(0.81*sin(x/2)**2 - 1)*sin(x/2)**2)

# %%
sp.plot(f,(x,0.01,2*sp.pi))
